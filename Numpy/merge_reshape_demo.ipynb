# %%
import pandas as pd

# %%
expences = pd.DataFrame([
    {"category": "food",     "amount": 250,   "city": "Delhi"},
    {"category": "travel",   "amount": 1200,  "city": "Mumbai"},
    {"category": "shopping", "amount": 500,   "city": "Delhi"},
    {"category": "travel",   "amount": None,  "city": "Mumbai"},   # missing!
])

# %%
budgets = pd.DataFrame([
    {"category": "food", "monthly_budget": 1000},
    {"category": "travel", "monthly_budget": 3000},
])

# %%
expences.merge(budgets, on="category",how="left");

# %%
print(expences);
# Out:
#    category  amount    city
# 0      food   250.0   Delhi
# 1    travel  1200.0  Mumbai
# 2  shopping   500.0   Delhi
# 3    travel     NaN  Mumbai

# %%
merged = expences.merge(budgets, on="category",how="left");

# %%
print(merged)
# Out:
#    category  amount    city  monthly_budget
# 0      food   250.0   Delhi          1000.0
# 1    travel  1200.0  Mumbai          3000.0
# 2  shopping   500.0   Delhi             NaN
# 3    travel     NaN  Mumbai          3000.0

# %%
pivot = expences.pivot_table(values="amount",index="category",columns="city")

# %%
print(pivot)
# Out:
# city      Delhi  Mumbai
# category
# food      250.0     NaN
# shopping  500.0     NaN
# travel      NaN  1200.0
