# %%
import pandas as pd

# %%
expenses = pd.DataFrame([
    {"category": "food",     "amount": 250,   "city": "Delhi"},
    {"category": "travel",   "amount": 1200,  "city": "Mumbai"},
    {"category": "shopping", "amount": 500,   "city": "Delhi"},
    {"category": "travel",   "amount": 1090,  "city": "Mumbai"}, 
    {"category": "food",     "amount": 290,   "city": "Delhi"},
    {"category": "travel",   "amount": 1900,  "city": "Mumbai"},
    {"category": "shopping", "amount": 1000,   "city": "Delhi"},
    {"category": "travel",   "amount": 1230,  "city": "Mumbai"}, 
])

# %%
expenses.index = range(1, len(expenses) + 1)

# %%
expenses.to_csv("expenses.csv",index=False)

# %%
expenses.to_json("expenses.json",orient="records",indent=2)

# %%
expenses.to_parquet("expenses.parquet")

# %%
from_csv = pd.read_csv("expenses.csv")

# %%
print(from_csv)
# Out:
#    category  amount    city
# 0      food     250   Delhi
# 1    travel    1200  Mumbai
# 2  shopping     500   Delhi
# 3    travel    1090  Mumbai
# 4      food     290   Delhi
# 5    travel    1900  Mumbai
# 6  shopping    1000   Delhi
# 7    travel    1230  Mumbai

# %%
from_json = pd.read_json("expenses.json")
print(from_json)
# Out:
#    category  amount    city
# 0      food     250   Delhi
# 1    travel    1200  Mumbai
# 2  shopping     500   Delhi
# 3    travel    1090  Mumbai
# 4      food     290   Delhi
# 5    travel    1900  Mumbai
# 6  shopping    1000   Delhi
# 7    travel    1230  Mumbai

# %%
from_parquet = pd.read_parquet("expenses.parquet")
print(from_parquet)
# Out:
#    category  amount    city
# 1      food     250   Delhi
# 2    travel    1200  Mumbai
# 3  shopping     500   Delhi
# 4    travel    1090  Mumbai
# 5      food     290   Delhi
# 6    travel    1900  Mumbai
# 7  shopping    1000   Delhi
# 8    travel    1230  Mumbai

# %%
expenses.to_csv("expenses_with_index.csv")
